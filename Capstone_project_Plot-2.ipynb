# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#getting the dataset from the files
x1 = pd.read_csv('C:/Users/LENOVO/Downloads/graduate-admissions/Admission_Predict_Ver1.1.csv')
x2 = pd.read_csv('C:/Users/LENOVO/Downloads/graduate-admissions/Admission_Predict_Ver1.1.csv')

# %%
#columns
x1.columns
#x2.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
#getting the plots
gre_score = x1['GRE Score']
toefl_score = x1['TOEFL Score']
University_rating = x1['University Rating']
sop = x1['SOP']
lor = x1['LOR ']
cgpa = x1['CGPA']
publication = x1['Research']
chances = x1['Chance of Admit ']

# %%
#plot of gre-score vs chances
plt.scatter(gre_score, chances)
plt.xlabel('GRE Scores')
plt.ylabel('Chances')
plt.show()

# %%
University_rating.unique()
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
#plot of toefl-score vs chances
plt.scatter(toefl_score, chances)
plt.xlabel('TOEFL Scores')
plt.ylabel('Chances')
plt.show()

# %%
#plot of gre-scores with reference to University rating
plt.scatter(x = gre_score, y = chances, c = University_rating, alpha = 0.8)
plt.xlabel('GRE Scores')
plt.ylabel('Chances')
plt.show()

# %%
#plot of Toefl-scores with reference to University rating
plt.scatter(x = toefl_score, y = chances, c = University_rating, alpha = 0.8)
plt.xlabel('TOEFL Scores')
plt.ylabel('Chances')
plt.show()

# %%
#plot of gre-scores with reference to LORS
plt.scatter(x = gre_score, y = chances, c = lor, alpha = 0.8)
plt.xlabel('GRE Scores')
plt.ylabel('Chances')
plt.show()

# %%
#plot of gre-scores with reference to LORs
plt.scatter(x = toefl_score, y = chances, c = lor, alpha = 0.8)
plt.xlabel('Toefl-score')
plt.ylabel('Chances')
plt.show()

# %%
#plot of gre-scores with reference to Research
plt.scatter(x = gre_score, y = chances, c = publication, alpha = 0.8)
plt.xlabel('GRE Scores')
plt.ylabel('Chances')
plt.show()

# %%
#plot of gre-scores with reference to Research publication
plt.scatter(x = toefl_score, y = chances, c = publication, alpha = 0.8)
plt.xlabel('TOEFL-Scores')
plt.ylabel('Chances')
plt.show()

# %%
#plot of gre-scores with reference to CGPA
plt.scatter(x = gre_score, y = chances, c = cgpa, alpha = 1)
plt.xlabel('GRE Scores')
plt.ylabel('Chances')
plt.show()

# %%
#plot of gre-scores with reference to CGPA
plt.scatter(x = toefl_score, y = chances, c = cgpa, alpha = 1)
plt.xlabel('TOEFL Scores')
plt.ylabel('Chances')
plt.show()
